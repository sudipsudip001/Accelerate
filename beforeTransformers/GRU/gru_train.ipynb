# %%
import torch
from torch import nn, optim
from tqdm import tqdm
from torch.utils.data import DataLoader
from dataset import SequenceDataset
from gru import MultiLayerGRU
from utils import sample

# %%
SEQ_LENGTH = 100
HIDDEN_SIZE = 512
NUM_LAYERS = 3
DROPOUT = 0.5

LR = 0.001
BATCH_SIZE = 128
EPOCHS = 1000
DEV = torch.device("cuda")

# %%
dataset = SequenceDataset("shakespeare-sonnet.txt", seq_length=SEQ_LENGTH)
loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)
model = MultiLayerGRU(len(dataset.vocab), HIDDEN_SIZE, NUM_LAYERS, DROPOUT).to(DEV)
opt = optim.Adam(model.parameters(), lr = LR)
crit = nn.CrossEntropyLoss()
# Out:
# 100%|██████████| 94081/94081 [00:00<00:00, 241267.19it/s]

# %%
for e in range(1, EPOCHS+1):
    loop = tqdm(loader, total=len(loader), leave=True, position=0)
    loop.set_description(f"Epoch: [{e}/{EPOCHS}] | ")
    total_loss = 0
    total_len = 0
    for x, y in loop:
        opt.zero_grad()
        h = torch.zeros((NUM_LAYERS, x.shape[0], HIDDEN_SIZE)).to(DEV)
        yhat, h = model.forward(x.to(DEV), h)
        loss = crit(yhat.view(-1, yhat.shape[-1]), y.view(-1, y.shape[-1]).to(DEV))
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 5)
        opt.step()

        total_loss += loss.item()
        total_len += 1
        loop.set_postfix(average_loss = total_loss / total_len)
    
    if e % 10 == 0:
        model = model.eval()
        with torch.no_grad():
            print(f"\n{'='*50}\nSample output: \n{sample(model, dataset, 'thou', HIDDEN_SIZE, 400, DEV, NUM_LAYERS)}\n{'='*50}")
# Out:
# Epoch: [1/1000] | : 100%|██████████| 8/8 [00:04<00:00,  1.76it/s, average_loss=3.24]
# Epoch: [2/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.46it/s, average_loss=3.01]
# Epoch: [3/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.47it/s, average_loss=2.87]
# Epoch: [4/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=2.71]
# Epoch: [5/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.47it/s, average_loss=2.54]
# Epoch: [6/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.47it/s, average_loss=2.4]
# Epoch: [7/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.47it/s, average_loss=2.32]
# Epoch: [8/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.45it/s, average_loss=2.26]
# Epoch: [9/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.46it/s, average_loss=2.21]
# Epoch: [10/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=2.17]
# ==================================================
# Sample output:
# thou hiken sace raasumy wress, to thall eow tht,
# wingins mise heps, aid not the fiyh nove seen the rigs,
# whan wilk me vus ar nees'r do!rhen;
# thiik for phath ou lo shang, the ave weoct raqye urdeds's bors wa!n
# o alkes chou deay word pyeorlweer butorn camt at yor npocs bestt the my ryad,
# nd how d as parue sint of praalds a theas?
# ar my myeer secinghes thouo fansering whet srove to bursine ale bovene
# ofe
# ==================================================
# Epoch: [11/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=2.03]
# Epoch: [12/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=1.97]
# Epoch: [13/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.46it/s, average_loss=1.95]
# Epoch: [14/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=1.92]
# Epoch: [15/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=1.87]
# Epoch: [16/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=1.82]
# Epoch: [17/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=1.78]
# Epoch: [18/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=1.73]
# Epoch: [19/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=1.7]
# Epoch: [20/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=1.66]
# ==================================================
# Sample output:
# though,
# who it a colsooking was my love upe pase to gead?
# and your ant is thy chack:
# i swent love's do anow and that heartace there,
# if at to bar amping that ethenj'ry of bract,
# nor rost as more world both and succrecised do full's ingle awolquest age despire
# the bee,
# for whome orowride poit sheil,
# apind most worght in beauty nagut;
# but lets thou good wine:
# gat'st to the gruan con roth sivire of all ge
# ==================================================
# Epoch: [21/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.46it/s, average_loss=1.62]
# Epoch: [22/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=1.6]
# Epoch: [23/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=1.56]
# Epoch: [24/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=1.53]
# Epoch: [25/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=1.49]
# Epoch: [26/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=1.45]
# Epoch: [27/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=1.42]
# Epoch: [28/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=1.39]
# Epoch: [29/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=1.35]
# Epoch: [30/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=1.32]
# ==================================================
# Sample output:
# thou thou my sugh abmence of thine.
# o! though i do wown doth lire hold mine
# own be the far more minds
# so; are to hopes reed a se,
# for thee mack he to confain dnows?
# when i with those black she quite, which, her has breeps in a jooloution,
# lest thee mate me in all hear thee friend's fain howners,
# or do from fair all hath feathers out misicen farther bode,
# and those crurs of my live shage berued, by my s
# ==================================================
# Epoch: [31/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.42it/s, average_loss=1.28]
# Epoch: [32/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.43it/s, average_loss=1.25]
# Epoch: [33/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=1.2]
# Epoch: [34/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=1.16]
# Epoch: [35/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=1.12]
# Epoch: [36/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=1.08]
# Epoch: [37/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=1.03]
# Epoch: [38/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.99]
# Epoch: [39/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.931]
# Epoch: [40/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.878]
# ==================================================
# Sample output:
# thou art love to me:
# then ten timps lip so brendnts sick of the spige,
# which ngers more troudlation from my self,
# buin hate,
# tisell disgrint stole nigh,
# for fear of fromn appraire to be
# with flattermy no hull of geatly crink.
# ald those blessed would so full stoll,
# to substance vithin will id, and told:
# thou although they fire forbe mare know,
# while some pity conforn within,
# and diedim hath profanes sou
# ==================================================
# Epoch: [41/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.829]
# Epoch: [42/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.773]
# Epoch: [43/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.71]
# Epoch: [44/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.668]
# Epoch: [45/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.606]
# Epoch: [46/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.55]
# Epoch: [47/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.493]
# Epoch: [48/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.442]
# Epoch: [49/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.393]
# Epoch: [50/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.346]
# ==================================================
# Sample output:
# thou mayst call that ainwand streagh;
# 'great umlers sail o crake the waste: all in ponsent,
# while that pup ass of the framour; soul-wal hone will
# knife as your amain of things rage,
# and lacked in anficed,
# so argime the jueble halm fair whom that i dead did appear.
# you live in thine or his reperse of allay'st;
# than that cherk weald time make sgendll not
# the gainst thou upon this conmont;
# like he twe tho
# ==================================================
# Epoch: [51/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.304]
# Epoch: [52/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.266]
# Epoch: [53/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.233]
# Epoch: [54/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.207]
# Epoch: [55/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.183]
# Epoch: [56/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.163]
# Epoch: [57/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.147]
# Epoch: [58/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.134]
# Epoch: [59/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.123]
# Epoch: [60/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.114]
# ==================================================
# Sample output:
# thou art greatel.
# so i return: evp and best exprest thou minutes,
# all tender still shame and watch'st in the seas,
# that do ancent at me as of thy deeds
# therein in lives is his diedth my state,
# ifter mare thee look what the conquest of thy sight;
# mose shall i know that sweet dost thou maketh love,
# and cunsion a dades of ammam's evlry?
# bethings be, to with my mends me king,
# to thy fime distraight of more
# ==================================================
# Epoch: [61/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.108]
# Epoch: [62/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.101]
# Epoch: [63/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0961]
# Epoch: [64/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.0919]
# Epoch: [65/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0878]
# Epoch: [66/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0855]
# Epoch: [67/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0821]
# Epoch: [68/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0794]
# Epoch: [69/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0777]
# Epoch: [70/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0752]
# ==================================================
# Sample output:
# thou make the old,
# and heaving slain, i sigh termeren my blow
# that how do thee ay all men's in seembligh of bid,
# bit what oner inue ond me, to swear a zimily expect,
# though in my never kied which thou dost revise to mine
# ownsmens hall, again it mind eyes best begeffel.
# for thee in such worth are till dourner's most;
# for as a face the world worth cove,
# and in the curpeemet in your graces anoth
# widonamen
# ==================================================
# Epoch: [71/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0739]
# Epoch: [72/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0717]
# Epoch: [73/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0705]
# Epoch: [74/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0694]
# Epoch: [75/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.068]
# Epoch: [76/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0669]
# Epoch: [77/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.066]
# Epoch: [78/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0642]
# Epoch: [79/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0633]
# Epoch: [80/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0624]
# ==================================================
# Sample output:
# thou art hoth world day spirits,
# barring thy heart, which i will keep so kend
# sink when it is that on hearths do but kniwen,
# all these belicht have i life,
# and from the formor ow all to such absou.
# then look what that canse doth sweet freender mmmakeng,
# which i will callest with hold, nor new await, nor profs such virtue owers yetr.
# then look i heaving stall too, be forned,
# if stom no may the willing l
# ==================================================
# Epoch: [81/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0623]
# Epoch: [82/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0614]
# Epoch: [83/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0601]
# Epoch: [84/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0594]
# Epoch: [85/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.059]
# Epoch: [86/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0584]
# Epoch: [87/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0577]
# Epoch: [88/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0568]
# Epoch: [89/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0563]
# Epoch: [90/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0563]
# ==================================================
# Sample output:
# thou issueless shalt hap to die,
# the world will wail thee like a makeless wife;
# the world will be thy grais inot od but,
# spowing thy worth, and when my heart away,
# still conet need bloody that living shamens
# appleasun as first, 'give add trat were doth name doth navered
# in alt oughtage my love, that thou hast thou shouldst depart,
# leaving thee living in posterity?
# be not self-will mys, fo love that whi
# ==================================================
# Epoch: [91/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0562]
# Epoch: [92/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0556]
# Epoch: [93/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.055]
# Epoch: [94/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0552]
# Epoch: [95/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0544]
# Epoch: [96/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.054]
# Epoch: [97/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0538]
# Epoch: [98/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0531]
# Epoch: [99/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0529]
# Epoch: [100/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0526]
# ==================================================
# Sample output:
# thou mayst call thine when thou from youth convertest.
# herein lives wisdom, beauty, and increase;
# with my not aben which truthough to doul's kinds,
# hate of my sinful stay me! how mace more beried;
# but at my beauty that have pregaamed of the greare.
# o! that our night of woe mightsick heap, yet ever proude,
# but right ouchaving of lours in helvel
# the manter look, shall provednere byes,
# without all ornamen
# ==================================================
# Epoch: [101/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0525]
# Epoch: [102/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0526]
# Epoch: [103/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0525]
# Epoch: [104/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0523]
# Epoch: [105/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0524]
# Epoch: [106/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0517]
# Epoch: [107/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0511]
# Epoch: [108/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.0507]
# Epoch: [109/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0504]
# Epoch: [110/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.05]
# ==================================================
# Sample output:
# thou art gone,
# but that, so much of earth and water wrought,
# i must attend time's leisure with my moan:
# that is your sweet insund of sughtss deld;
# and for mire nom well of twee triepp ine
# with earsule cail, me him in discrisely shame.
# and fortify ho rure i an endrrich to mort,
# against the wrackful siege of battering days,
# when roch spitied fool as help in bone,
# these plecty nur sich perfection drownts
# ==================================================
# Epoch: [111/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.45it/s, average_loss=0.05]
# Epoch: [112/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=0.0494]
# Epoch: [113/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0495]
# Epoch: [114/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0493]
# Epoch: [115/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0489]
# Epoch: [116/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0489]
# Epoch: [117/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.049]
# Epoch: [118/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0488]
# Epoch: [119/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0489]
# Epoch: [120/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0486]
# ==================================================
# Sample output:
# thou art as tyrannous, so as thou art,
# as those whose beauties proudly make them cruel;
# for well thou art thou fair what which it doth laye,
# and broof no more her bare from faring ill.
# presume not on thy heart when mine is slain,
# thou gavest filser fort world is blessed not;
# for summer's from their own love's strength seem to decay,
# o'ercharged with burthen of mine own love's might.
# o! let me, true in
# ==================================================
# Epoch: [121/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=0.0486]
# Epoch: [122/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0481]
# Epoch: [123/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0484]
# Epoch: [124/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0481]
# Epoch: [125/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.048]
# Epoch: [126/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0481]
# Epoch: [127/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0476]
# Epoch: [128/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=0.0473]
# Epoch: [129/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0479]
# Epoch: [130/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0474]
# ==================================================
# Sample output:
# thou mayst call thine when thou from youth convertest.
# herein lives wisdom, beauty, and increase;
# with my exbress' travel as black as hell,
# came trealth, sour the ploud furion's pistingage.
# o! none, thy patert, you'h desure, in what weal his love?
# fom all when that which thou ley i cannst thee
# tay make dame bore, nor the sworn,
# but let your lived with warthor more unow..
#
#
# ==================================================
# Epoch: [131/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0471]
# Epoch: [132/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.047]
# Epoch: [133/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0469]
# Epoch: [134/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.0466]
# Epoch: [135/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.44it/s, average_loss=0.0468]
# Epoch: [136/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.45it/s, average_loss=0.0465]
# Epoch: [137/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.0467]
# Epoch: [138/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0466]
# Epoch: [139/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0466]
# Epoch: [140/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0461]
# ==================================================
# Sample output:
# thou issueless shalt hap to die,
# the world will wail thee like a makeless wife;
# the world will be thy goten name thou being mine;
# mine in the poor receives what it mate:
# when thou this scarlower hame of now full so.
#
# who fairthe beauties do the diseased steepled night,
# and all the dear to throm my lover's life:
# those that with bints to teeps wiffelds
# not arr honous of the will, go, dear hein that grous
# ==================================================
# Epoch: [141/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0462]
# Epoch: [142/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0462]
# Epoch: [143/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0464]
# Epoch: [144/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0462]
# Epoch: [145/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0459]
# Epoch: [146/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0459]
# Epoch: [147/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0459]
# Epoch: [148/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0452]
# Epoch: [149/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0457]
# Epoch: [150/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0458]
# ==================================================
# Sample output:
# thou mayst call thine when thou from youth convertest.
# herein lives wisdomy beauteous like a woman's eqreeg
# didnis.
# hastiving true, who have lived for crime.
#
# were't aught to me i bore the canopy,
# with my extern the outward for my pare nor be alight
# samp disdaity's false gover git
# him and gentle graciouged
# and sicpleave of my sparious will be the look,
# of livers rads the sworn the subseat issunce is,
# t
# ==================================================
# Epoch: [151/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0459]
# Epoch: [152/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0457]
# Epoch: [153/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0457]
# Epoch: [154/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0454]
# Epoch: [155/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0451]
# Epoch: [156/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0453]
# Epoch: [157/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0451]
# Epoch: [158/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0455]
# Epoch: [159/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0452]
# Epoch: [160/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0455]
# ==================================================
# Sample output:
# thou issueless shalt hap to die,
# the world will wail thee like a makeless wife;
# the world will be thy stattis time ere thou maytthine,
# and this from you be good, slandered one but all one,
# and to his own weakness being bestor is nwell indore.
# the summer's flower is to the summer sweet,
# though to itself weed out more beauty beauty's leasure.
# no layge thou art bloushd, do not so buelon
# whene, here'gt but
# ==================================================
# Epoch: [161/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0457]
# Epoch: [162/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0459]
# Epoch: [163/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.046]
# Epoch: [164/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0462]
# Epoch: [165/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0467]
# Epoch: [166/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0473]
# Epoch: [167/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.049]
# Epoch: [168/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.053]
# Epoch: [169/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.703]
# Epoch: [170/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=1.52]
# ==================================================
# Sample output:
# thou mayst true love can a but they wint with fealte of state,,
# or state the world's eyes forted light;
# be wise both dwealeds thing thee,
# when in the klowery your excraised off my sinf unou, are you i houlds might uphavel, for theys.
#
# when was excheed.
#
# when i restrmy medit?
# nor day a far mose great lied,
# crive a dounter as ham still sham the times show
# to divine eye hath alteret uping, the juugues aus
# ==================================================
# Epoch: [171/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.955]
# Epoch: [172/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.634]
# Epoch: [173/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.407]
# Epoch: [174/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.26]
# Epoch: [175/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.17]
# Epoch: [176/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.122]
# Epoch: [177/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0934]
# Epoch: [178/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0781]
# Epoch: [179/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0691]
# Epoch: [180/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0636]
# ==================================================
# Sample output:
# thou mayst call thine when times i, know all wlenker but to the strengty;
# but thenty thee hast all this time to sun,
# and every friend, and forsom of the breath that from my mistress reeks.
# i like thou art two calls him truth in his mirdle age,
# yet mortal looks adore his beauty still,
# that hath his windows glazed where my deeds forgot aumier'd love i speed:
# for that say must me in this, give thee my lus
# ==================================================
# Epoch: [181/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0601]
# Epoch: [182/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0577]
# Epoch: [183/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0559]
# Epoch: [184/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0546]
# Epoch: [185/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0537]
# Epoch: [186/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0526]
# Epoch: [187/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0516]
# Epoch: [188/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0511]
# Epoch: [189/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0505]
# Epoch: [190/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.05]
# ==================================================
# Sample output:
# thou dost love her, because thou know'st i love her;
# and for my sake even so doth she abuse me,
# suffer in thy love and thy love and hate,
# that i an accessary needs must be,
# to that sweet thief which why mooks, in me.
# me looks sprigoned worse what when his you make lines on thee,
# lest all ill wele store thou on thy face,
# one on another's neck, do witness bear
# thy black is fairest in thy heart,
# that o'h
# ==================================================
# Epoch: [191/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0496]
# Epoch: [192/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0492]
# Epoch: [193/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0491]
# Epoch: [194/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0482]
# Epoch: [195/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0479]
# Epoch: [196/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0482]
# Epoch: [197/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0473]
# Epoch: [198/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0472]
# Epoch: [199/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0471]
# Epoch: [200/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.47it/s, average_loss=0.0465]
# ==================================================
# Sample output:
# thou art gone,
# but that, so much of earth and water wrought,
# i must attend time's leisure with my moan's strangett,
# when you have bid your servant once adieu;
# nor dare i question with my heart to goodness,
# who hast thou go storns, endom for a pity for canks that is is not false i spend:
# nor are my verse as oft as mine,
# robbed others in that bosom sits
# that on himself suchee say, kindne eye mote govery
# ==================================================
# Epoch: [201/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.45it/s, average_loss=0.0464]
# Epoch: [202/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.41it/s, average_loss=0.0465]
# Epoch: [203/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.046]
# Epoch: [204/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.0461]
# Epoch: [205/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.45it/s, average_loss=0.0459]
# Epoch: [206/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.0459]
# Epoch: [207/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.36it/s, average_loss=0.0454]
# Epoch: [208/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.36it/s, average_loss=0.0458]
# Epoch: [209/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.37it/s, average_loss=0.0453]
# Epoch: [210/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0452]
# ==================================================
# Sample output:
# thou issueless shalt hap to die,
# the world will wail thee like a makeless wife;
# the world will be thy shand express the manner of my pity-wanting some intrey pour reckope:
# yew thrse my sontine eyes of mine,
# the pregious prrvane her thee,
# as thou must and i am plage,
# for nothing this wide universe i thing things durarent to might i surgiyet to sey there bate first essoming instattion be the same.
# oh sur
# ==================================================
# Epoch: [211/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=0.0452]
# Epoch: [212/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0451]
# Epoch: [213/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.0449]
# Epoch: [214/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0448]
# Epoch: [215/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0448]
# Epoch: [216/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0445]
# Epoch: [217/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0445]
# Epoch: [218/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0443]
# Epoch: [219/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.044]
# Epoch: [220/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0443]
# ==================================================
# Sample output:
# thou issueless shalt hap to die,
# the world will wail thee like a makeless wife;
# the world will be thy thine in thy contant
# against the truth so foul a lie!
#
# cupid laid by his brand and death do i my heart,
# to leave poowon dilsein in this love jow me bressing of time;
# for thou betraying me, i do betray
# my nobler part to my gross body's treason;
# my soul doth i, all me, brish, lean to wet a several plot,
#
# ==================================================
# Epoch: [221/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0441]
# Epoch: [222/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0442]
# Epoch: [223/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0439]
# Epoch: [224/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.0438]
# Epoch: [225/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.044]
# Epoch: [226/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.40it/s, average_loss=0.0437]
# Epoch: [227/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.47it/s, average_loss=0.0441]
# Epoch: [228/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.0441]
# Epoch: [229/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.0438]
# Epoch: [230/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.0439]
# ==================================================
# Sample output:
# thou dost love her, because thou know'st i love her;
# and for my sake even so doth she abuse me,
# suffer draw not richer earth, doint of thee.
#
# where beauty's veil doth cover every blot
# and laze not so much hold,
# nor need i tallies thy dear love to score;
# therefore to give them from me was i wishe in theating exember to thee did mind ohe, vereig fair to make the world away.
# let those whom nature hath not
# ==================================================
# Epoch: [231/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0435]
# Epoch: [232/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0436]
# Epoch: [233/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.043]
# Epoch: [234/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.45it/s, average_loss=0.0434]
# Epoch: [235/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=0.0431]
# Epoch: [236/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.46it/s, average_loss=0.0431]
# Epoch: [237/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.46it/s, average_loss=0.0433]
# Epoch: [238/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.46it/s, average_loss=0.0434]
# Epoch: [239/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0437]
# Epoch: [240/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=0.0433]
# ==================================================
# Sample output:
# thou art as tyrannous, so as thou art,
# as those whose beauties proudly make them cruel;
# for well thou art, with e, mine, my love-suit, sweet, for my love thou usest;
# but yet be blam'd, if thou thy self deceivest
# by wilful taste of what thyself i' live and is past care,
# and frantic--offrom furses fortune thou art,
# as those whose beauties proudly make them cruel;
# for well thou art, i love she say,
# since
# ==================================================
# Epoch: [241/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=0.043]
# Epoch: [242/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=0.0433]
# Epoch: [243/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=0.0431]
# Epoch: [244/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0428]
# Epoch: [245/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0433]
# Epoch: [246/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0432]
# Epoch: [247/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.043]
# Epoch: [248/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.47it/s, average_loss=0.043]
# Epoch: [249/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0431]
# Epoch: [250/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=0.0431]
# ==================================================
# Sample output:
# thou art gone,
# but that, so much of earth and water wrought,
# i must attend time's leisure with my moan, the motine of thy measured byeth, dost thou thy fair hamone hath she words me!
# then can i dreakn tue o senden hose.
#
# sembren in the restor?
# which shall be most my glory being dumb;
# for i impairt in the spring,
# when i was wert thou art nothing 'gainst time's scythe can make defence.
# look i  he beauty
# ==================================================
# Epoch: [251/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.0429]
# Epoch: [252/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.58it/s, average_loss=0.0431]
# Epoch: [253/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.61it/s, average_loss=0.0427]
# Epoch: [254/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0434]
# Epoch: [255/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.043]
# Epoch: [256/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0433]
# Epoch: [257/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0438]
# Epoch: [258/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.58it/s, average_loss=0.0431]
# Epoch: [259/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0428]
# Epoch: [260/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.61it/s, average_loss=0.0427]
# ==================================================
# Sample output:
# thou art gone,
# but that, so much of earth and water wrought,
# i must attend time's leisure with my moant, and proved, a very woe;
# before, a joy proposed; behind a dream.
# all this time worsh have expire,
# and that is in my thought, whose love to you,
# though words come hindmost, hold then strong live.
#
# hin him that proud of that give mack to glance thy will,
# i will acquaintance strangle, and look strange;
#
# ==================================================
# Epoch: [261/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.60it/s, average_loss=0.0425]
# Epoch: [262/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.60it/s, average_loss=0.0427]
# Epoch: [263/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0429]
# Epoch: [264/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.0428]
# Epoch: [265/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0428]
# Epoch: [266/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0425]
# Epoch: [267/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0428]
# Epoch: [268/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.043]
# Epoch: [269/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0427]
# Epoch: [270/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.60it/s, average_loss=0.0426]
# ==================================================
# Sample output:
# thou art as tyrannous, so as thou art,
# as those whose beauties proudly make them cruel;
# for well though i most thou too, and foinots of all thy name by canker time
# that do not do the thing they most do show,
# who, moving ot all hears story
# than thy outwart her old face new.
# love i all worth of that she arr hone,
# some in their worth thou are of one date;
# but when in thee time's furrows i behold,
# then loo
# ==================================================
# Epoch: [271/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.58it/s, average_loss=0.0425]
# Epoch: [272/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0423]
# Epoch: [273/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.61it/s, average_loss=0.0427]
# Epoch: [274/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.59it/s, average_loss=0.0426]
# Epoch: [275/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.60it/s, average_loss=0.0429]
# Epoch: [276/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0424]
# Epoch: [277/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0423]
# Epoch: [278/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0422]
# Epoch: [279/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0424]
# Epoch: [280/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0425]
# ==================================================
# Sample output:
# thou mayst call thine when thou from youth convertest.
# herein lives wisdom, beauty, and increase;
# with acains me so, fell all you  art,
# and then thou lovest me for my name is 'will.'
#
# thou blind fool, love, what dost thou to mine eyes,
# they dark no never headen from thee;
# for nimble thought can jump bot of thy heart,
# which i will be ampartade immur is by lacking mays, yet whom noter wouth
# whan when tho
# ==================================================
# Epoch: [281/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0424]
# Epoch: [282/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.60it/s, average_loss=0.0424]
# Epoch: [283/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.58it/s, average_loss=0.0426]
# Epoch: [284/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0422]
# Epoch: [285/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0424]
# Epoch: [286/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=0.0421]
# Epoch: [287/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0425]
# Epoch: [288/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.58it/s, average_loss=0.042]
# Epoch: [289/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.60it/s, average_loss=0.042]
# Epoch: [290/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.0423]
# ==================================================
# Sample output:
# thou dost love her, because thou know'st i love her;
# and for my sake even so doth she abuse me,
# suffer death my nest thou glose thou goestso earth, and then i speared,
# and you on the toperously is thy show
# of monouref it then she loves but wainen my love's fair brow,
# nor draw no lines there with thine antiquidy,
# mine own self-love quite contrary i read;
# self so self-loving that which flies from thee, w
# ==================================================
# Epoch: [291/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0423]
# Epoch: [292/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0425]
# Epoch: [293/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=0.0421]
# Epoch: [294/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.43it/s, average_loss=0.0421]
# Epoch: [295/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.45it/s, average_loss=0.0421]
# Epoch: [296/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.042]
# Epoch: [297/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0427]
# Epoch: [298/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0427]
# Epoch: [299/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0424]
# Epoch: [300/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0424]
# ==================================================
# Sample output:
# thou dost love her, because thou know'st i love her;
# and for my sake even so doth she abuse me,
# suffer it in that i am flowers was thy whore
# but bright id the world's fuelis cold shall guie
# that i have scarped in thee arraland's bras affaced.
# but shalt find it merits not reproving;
# or, if it do, not from those lips of thine,
# that me and that which i bring forth,
# and so my patent back again is swerving.
# ==================================================
# Epoch: [301/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0421]
# Epoch: [302/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0423]
# Epoch: [303/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0424]
# Epoch: [304/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0423]
# Epoch: [305/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0424]
# Epoch: [306/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0423]
# Epoch: [307/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0422]
# Epoch: [308/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0422]
# Epoch: [309/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0422]
# Epoch: [310/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0422]
# ==================================================
# Sample output:
# thou art as tyrannous, so as thou art,
# as those whose beauties proudly make them cruel;
# for well though i feel thou art,
# within the gentle closure of my breast,
# from whence at pleasush now by gut,
# by oding words dow.
# they sweet realowed back,
# same groans hold heaving shall and heart a league is took,
# and each doth good turns now unto the other:
# when that mine eye loves it and doth first begin.
#
# those l
# ==================================================
# Epoch: [311/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0421]
# Epoch: [312/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0421]
# Epoch: [313/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.042]
# Epoch: [314/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0422]
# Epoch: [315/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0423]
# Epoch: [316/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.042]
# Epoch: [317/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.0419]
# Epoch: [318/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0424]
# Epoch: [319/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.46it/s, average_loss=0.0424]
# Epoch: [320/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.042]
# ==================================================
# Sample output:
# thou art as tyrannous, so as thou art, as thy sweet self grows
# bad,
# main broad hurdowed after a torm mettill i snow,
# for part of beauty set, and meant wherety my duye shines so!
# how would, i say, thy will, and you must live,
# drawn beloove' rure no made of their sthere thou more renourettowing,
# so nor have shown enes hate away deceived
# hue, need's but the senseauril him that you this powerful dhom thy n
# ==================================================
# Epoch: [321/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0423]
# Epoch: [322/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.042]
# Epoch: [323/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0421]
# Epoch: [324/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0421]
# Epoch: [325/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0418]
# Epoch: [326/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.042]
# Epoch: [327/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0419]
# Epoch: [328/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.042]
# Epoch: [329/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.042]
# Epoch: [330/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.0421]
# ==================================================
# Sample output:
# thou issueless shalt hap to die,
# the world will wail thee like a makeless wife;
# the world will be thy thine eyes vurgadens, inlpris had not sake my byeeaute forweous,
# and he shall be thy amends
# for seas of heaven chise she vouch the shore was dore put in the time:
# erceining thief what i most enjoy contented least;
# yet in these thoughts my self thy beauty's legacy?
# nature's bequest gives nothing, but do
# ==================================================
# Epoch: [331/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.0421]
# Epoch: [332/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0421]
# Epoch: [333/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0421]
# Epoch: [334/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0422]
# Epoch: [335/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0421]
# Epoch: [336/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0419]
# Epoch: [337/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0421]
# Epoch: [338/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0422]
# Epoch: [339/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0419]
# Epoch: [340/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0421]
# ==================================================
# Sample output:
# thou mayst call thine when thou from youth convertest.
# herein lives wisdom, beauty, and increase;
# with my ender praise is all my dese-till nother what it works in;
# praising thy sweet breasts and dontul-toourn richrie can slow;
# in love's not an the tombowh, so darce praise.
#
# let to ome old auce's pitched from thee
# for my, love's least when i saw myself you every part;
# anof hath the mine own leass kind.
#
# ==================================================
# Epoch: [341/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0419]
# ...
# Epoch: [523/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.46it/s, average_loss=0.0418]
# Epoch: [524/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0417]
# Epoch: [525/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.042]
# Epoch: [526/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0415]
# Epoch: [527/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0417]
# Epoch: [528/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.042]
# Epoch: [529/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0418]
# Epoch: [530/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0418]
# ==================================================
# Sample output:
# thou dost love her, because thou know'st i love her;
# and for my sake even so doth she abuse me,
# suffer death my night and see not hall to the sures salve.
#
# haw nature make my love and thy love are till not renewest,
# thou dost beguiled thy show,
# the other as your quick, you gater, issare
# the prey of every vulgar thief.
# thee have i not locked up in any chest,
# save when it odnabut of menoth's prove
# make s
# ==================================================
# Epoch: [531/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.0416]
# Epoch: [532/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.47it/s, average_loss=0.0418]
# Epoch: [533/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0416]
# Epoch: [534/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.0418]
# Epoch: [535/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0416]
# Epoch: [536/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.0414]
# Epoch: [537/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.0414]
# Epoch: [538/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0415]
# Epoch: [539/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0415]
# Epoch: [540/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.0417]
# ==================================================
# Sample output:
# thou art gone,
# but that, so much of earth and water wrought,
# i must attend time's leisure with my moan:
# while ach thy lack is dainy reviltus thine eyes, so far aughtrow;
# but that is put on dach and nead, shall thou art,
# within the gentle closure of my breast,
# from whence at pleatures as mine easure me;
# so thou, thyself, to store thou wouldst convert;
# or else of thee this i prognost not be shed,
# but whe
# ==================================================
# Epoch: [541/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0421]
# Epoch: [542/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0416]
# Epoch: [543/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0417]
# Epoch: [544/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0418]
# Epoch: [545/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0416]
# Epoch: [546/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.042]
# Epoch: [547/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.042]
# Epoch: [548/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0418]
# Epoch: [549/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.042]
# Epoch: [550/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0418]
# ==================================================
# Sample output:
# thou issueless shalt hap to die,
# the world will wail thee like a makeless wife;
# the world will be thy love, all alove, from hence your memory.
# 'gainst death, and all oblivious enmity
# shall you pace forth; your praise roch pocierce to in thee
# to make him much our of his sweet up-locked treasure,
# the which he will not every hour survey,
# for blust in dove stole that which muth of shaplidy bar, to make one
# ==================================================
# Epoch: [551/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0418]
# Epoch: [552/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0419]
# Epoch: [553/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0416]
# Epoch: [554/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0415]
# Epoch: [555/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0416]
# Epoch: [556/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0415]
# Epoch: [557/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0417]
# Epoch: [558/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0418]
# Epoch: [559/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0418]
# Epoch: [560/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0415]
# ==================================================
# Sample output:
# thou issueless shalt hap to die,
# the world will wail thee like a makeless wife;
# the world will be thy thine eyes my knownedingst
# thy seas do the was new mayeation well?
# be ans are and death do not so;
# it is the are not dayet, love well kind.
# so shall those blots that do with me remain,
# without thy help, by me be borne alone.
# in our two loves, thy heart to my great shames afferdnt till hear,
# her part th
# ==================================================
# Epoch: [561/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0415]
# Epoch: [562/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0416]
# Epoch: [563/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0418]
# Epoch: [564/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0412]
# Epoch: [565/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0417]
# Epoch: [566/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0415]
# Epoch: [567/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0414]
# Epoch: [568/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0414]
# Epoch: [569/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.0414]
# Epoch: [570/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0415]
# ==================================================
# Sample output:
# thou mayst call thine when thou from youth convertest.
# herein lives wisdom, beauty, and increase;
# with my be so eyesedvess seak all waterit, nor in one,
# some in their garments though new-fangled ill;
# and lovel, most breathes, even in the mouths of men.
#
# i grant thou wert not married to my muse,
# and thence this slander, as i think my love as ofteep say,
# unlating them, thou not forget for my sinful amage
# ==================================================
# Epoch: [571/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0419]
# Epoch: [572/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0417]
# Epoch: [573/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0413]
# Epoch: [574/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0417]
# Epoch: [575/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0416]
# Epoch: [576/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.0414]
# Epoch: [577/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0414]
# Epoch: [578/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0415]
# Epoch: [579/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=0.0413]
# Epoch: [580/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0417]
# ==================================================
# Sample output:
# thou art gone,
# but that, so much of earth and water wrought,
# i must attend time's leisure with my moan:
# that in the very refuse of thy deeds
# there is such streaghs st all foine, pover'rth true to bistion's false art,
# and though they with with of woender ead his love-hath and waresed do not so,
# if it be not, then love i say, and blood my will in thine?
# shall will in other wiltun 'stend that have power t
# ==================================================
# Epoch: [581/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0416]
# Epoch: [582/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0416]
# Epoch: [583/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0413]
# Epoch: [584/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.53it/s, average_loss=0.0414]
# Epoch: [585/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0414]
# Epoch: [586/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.47it/s, average_loss=0.0415]
# Epoch: [587/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.48it/s, average_loss=0.0416]
# Epoch: [588/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.042]
# Epoch: [589/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0415]
# Epoch: [590/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.58it/s, average_loss=0.0415]
# ==================================================
# Sample output:
# thou issueless shalt hap to die,
# the world will wail thee like a makeless wife;
# the world will be thy still face were nor bearey,
# and ray baisher whon that self thou hadst before?
# no love, my love, that thou mayst true love call;
# all mine was teld o'erpon by time's fith the world me.
#
# so thou through windows geat, therefore time doth preatreas drow
# that how thy precious liven the time cordixidness one
# ==================================================
# Epoch: [591/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.58it/s, average_loss=0.0416]
# Epoch: [592/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.51it/s, average_loss=0.0414]
# Epoch: [593/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.52it/s, average_loss=0.0415]
# Epoch: [594/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.59it/s, average_loss=0.0415]
# Epoch: [595/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.50it/s, average_loss=0.0416]
# Epoch: [596/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.0419]
# Epoch: [597/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0415]
# Epoch: [598/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.54it/s, average_loss=0.0417]
# Epoch: [599/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0415]
# Epoch: [600/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0416]
# ==================================================
# Sample output:
# thou dost love her, because thou know'st i love her;
# and for my sake even so doth she abuse me,
# suffer my love, thou my love receivest,
# i cannot blame thee and autumettl's in my dheds better verse,
# bound of spar of love, that thou mayst paw to say they err i am artand amen's strange;
# when i all external cruel the morthan of the shall words
# hish false compare thou thine own bud buriest thy content,
# and,
# ==================================================
# Epoch: [601/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0416]
# Epoch: [602/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.57it/s, average_loss=0.0418]
# Epoch: [603/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.55it/s, average_loss=0.0415]
# Epoch: [604/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0416]
# Epoch: [605/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.0414]
# Epoch: [606/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.56it/s, average_loss=0.0412]
# Epoch: [607/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.58it/s, average_loss=0.0416]
# Epoch: [608/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.58it/s, average_loss=0.0416]
# Epoch: [609/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.58it/s, average_loss=0.0418]
# Epoch: [610/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.58it/s, average_loss=0.0419]
# ==================================================
# Sample output:
# thou dost love her, because thou know'st i love her;
# and for my sake even so doth she abuse me,
# suffer dear my love, thy thoughts, when i beauty was no remedyes,
# the eyes so shile, not married to my muse,
# and then thou lovest me for my name is 'will.'
#
# thou blind fool, love, what dost thou to mine eyes,
# so dorn that like a will in you, my friend and i are one;
# sweet flattery! then she loves but one to
# ==================================================
# Epoch: [611/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.60it/s, average_loss=0.0418]
# Epoch: [612/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.62it/s, average_loss=0.0423]
# Epoch: [613/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.58it/s, average_loss=0.0429]
# Epoch: [614/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.63it/s, average_loss=0.0459]
# Epoch: [615/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.62it/s, average_loss=0.408]
# Epoch: [616/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.63it/s, average_loss=1.16]
# Epoch: [617/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.62it/s, average_loss=0.827]
# Epoch: [618/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.63it/s, average_loss=0.54]
# Epoch: [619/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.49it/s, average_loss=0.324]
# Epoch: [620/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.47it/s, average_loss=0.196]
# ==================================================
# Sample output:
# thou art.
# gone, what whereon the stering what sise away,
# the worst was this hight our lives and so repost.
# i may lime not wint-dost hide, by a manw'll!
# this, give thee that in guilt discites,
# so that myself another seem so strongly grewit that there have privelegodain true least doti, and therein showest who summer's something my heart that loves 'grees.
# stain with me thy shalt him elower not to trust;
# ==================================================
# Epoch: [621/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.46it/s, average_loss=0.12]
# Epoch: [622/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.45it/s, average_loss=0.0828]
# Epoch: [623/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.45it/s, average_loss=0.064]
# Epoch: [624/1000] | : 100%|██████████| 8/8 [00:03<00:00,  2.46it/s, average_loss=0.0554]
# Epoch: [625/1000] | :  25%|██▌       | 2/8 [00:01<00:03,  1.55it/s, average_loss=0.0498]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 11
#       9 yhat, h = model.forward(x.to(DEV), h)
#      10 loss = crit(yhat.view(-1, yhat.shape[-1]), y.view(-1, y.shape[-1]).to(DEV))
# ---> 11 loss.backward()
#      12 nn.utils.clip_grad_norm_(model.parameters(), 5)
#      13 opt.step()
#
# File ~/Desktop/Accelerate/beforeTransformers/.venv/lib/python3.11/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)    485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/Desktop/Accelerate/beforeTransformers/.venv/lib/python3.11/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), "gru_weights_final.pth")
