# %% [markdown]
# # Prompting
#
# A prompt is a natural language request submitted to a language model to receive a response back. After the model receives a prompt, depending on the type of model being used, it can generate text, embeddings, code, images, videos, music, and more.
#
# - *Prompt design*: process of creating prompts that elicit the desired response from language models.
# - *Prompt engineering*: iterative process of repeatedly updating prompts and assessing the model's responses.
#
# ### Components of a prompt
#
# - Task (required)
# - System instructions (optional)
# - Few-shot examples (optional)
# - Contextual information (optional)

# %% [markdown]
# ## 1. Task:
#     - the text in the prompt that you want the model to provide a response for.
#
# **Prompt:**
#
# Write a one-stanza poem about Captain Barktholomew, the most feared pirate dog of the seven seas.
#
# **Response:**
#
# Captain Barktholomew, with patch and with peg,
# The terror of parrots, the bane of each keg.
# His bark is a cutlass, his bite is a storm,
# He'll plunder your biscuits and leave you forlorn.

# %% [markdown]
# ## 2. System instructions:
#     - instructions that get passed to the model before any user input in the prompt.
#
# **System:**
#
# You are Captain Barktholomew, the most feared pirate dog of the seven seas. You are from the
# 1700s and have no knowledge of anything after that time. You only talk about topics related to
# being a pirate. End every message with "woof!"
#
# **Prompt:**
#
# Hello! Who might you be?
#
# **Response:**
#
# Avast there! You can call me Captain Barktholomew, the scourge of the seven seas!
#
# I'm a terror to landlubbers, a plunderer of the highest order, and a fearsome pirate of the
# deepest blue! I sail the seas in search of treasure and adventure, leaving a trail of
# laughter and dog biscuits in my wake! Don't let my fuzzy exterior fool you - I'm a cunning
# captain with a nose for treasure and a heart for adventure!
#
# Now, if you'll excuse me, I must away! There's a ship on the horizon, and it looks like they're
# carrying a chest full of dubloons! Yo ho ho, and a bottle of rum! Woof!

# %% [markdown]
# ## 3. Few-shot examples
#
#     - examples that you include in a prompt to show the model what getting it right looks like.
#
# **Prompt:**
#
# Classify the following as red wine or white wine:
#
# <examples>
#   Name: Chardonnay
#   Type: White wine
#   Name: Cabernet
#   Type: Red wine
#   Name: Moscato
#   Type: White wine
# </examples>
#
# Name: Riesling
# Type:
#
#
# **Response:**
#
# White wine

# %% [markdown]
# ## 4. Contextual information
#     - is information that you include in the prompt that the model uses or references when generating a response. (it can be tables, or text)
#
# **Prompt:**
#
# | Marble color | Number of marbles |
# | ------------ | ----------------- |
# | Red          | 12                |
# | Blue         | 28                |
# | Yellow       | 15                |
# | Green        | 17                |
#
# How many green marbles are there?
#
#
# **Response:**
#
# There are 17 green marbles.

# %% [markdown]
# ## Safety and fallback responses
#
# There maybe cases where the model is not expected to fulfill the user's requests, such as hate speech, harassment, sexually explicit and dangerous contents. In these cases the model refuses to respond and provides a fallback response.

# %% [markdown]
# ## Overview of prompting strategies
#
# Prompt engineering is a test-driven and iterative process that can enhance model performance. The prompt engineering workflow is given below:
#
# ![prompt engineering workflow](./prompt_workflow.png)
#
# Two aspects of a prompt that ultimately affects its effectiveness are: `content` and `strucuture`.
#
# - `content`: the model needs all relevant information associated with the task to complete it, which includes instructions, examples, contextual information, and so on.
# - `structure`: even when all required information is provided in the prompt, giving the information structure helps the model parse the information
#
# ### Components of a prompt
#
# | Component | Description | Example |
# |--|--|--|
# |Objective|What you want the model to achieve.|Your objective is to help students with math problem without giving them the answer|
# |Instructions|Step by step instructions on how to perform the task|1. Understand what the problem is asking. 2. Understand where the student is stuck. 3. Give a hint for the next step of the problem|
# |**OPTIONAL COMPONENTS**|
# |System Instructions|Involves controlling or altering the model's behavior across a set of tasks.|You are a coding expert that specializes in .....|
# |Persona|Who or what the model is acting as.|You are a math tutor here to help students with their math homework|
# |Constraints|Restrictions on what the model must adhere to when generating a response, including what the model can and can't do.|Don't give the answer to the student directly. Instead, give hints at the next step towards solving the problem.|
# |Tone|The tone of the response|Respond in a casual and technical manner|
# |Context|Any information that the model needs to refer to in order to perform the task at hand|A copy of the student's lesson plans for math|
# |Few-shot examples|Examples of what the response should look like for a given prompt|**input**: I'm trying to calculate how many golf balls can fit into a box that has one cubic meter into cubic centimeters and divided it by the volume of a golf ball in cubic centimeters. **output** Golf balls are spheres and cannot be packed into a space with perfect efficiency.|
# |Reasoning steps|Tell the model to explain its reasoning.|Explain your reasoning step-by-step.|
# |Response format|The format that you want the reponse to be in|Format your response in Markdown|
# |Recap|Concise repeat of the key points of the prompt, especially the constraints and response format, at the end of the prompt|Don't give away the answer and provide hints instead.|
# |Safeguards|Grounds the questions to the mission of the bot. Also called "safety rules"|N/A|

# %% [markdown]
# ### Sample prompt template:
#
#       <OBJECTIVE_AND_PERSONA>
#       You are a [insert a persona, such as a "math teacher" or "automotive expert"]. Your task is to...
#       </OBJECTIVE_AND_PERSONA>
#
#       <INSTRUCTIONS>
#       To complete the task, you need to follow these steps:
#       1.
#       2.
#       ...
#       </INSTRUCTIONS>
#
#       ------------- Optional Components ------------
#
#       <CONSTRAINTS>
#       Dos and don'ts for the following aspects
#       1. Dos
#       2. Don'ts
#       </CONSTRAINTS>
#
#       <CONTEXT>
#       The provided context
#       </CONTEXT>
#
#       <OUTPUT_FORMAT>
#       The output format must be
#       1.
#       2.
#       ...
#       </OUTPUT_FORMAT>
#
#       <FEW_SHOT_EXAMPLES>
#       Here we provide some examples:
#       1. Example #1
#           Input:
#           Thoughts:
#           Output:
#       ...
#       </FEW_SHOT_EXAMPLES>
#
#       <RECAP>
#       Re-emphasize the key aspects of the prompt, especially the constraints, output format, etc.
#       </RECAP>

# %% [markdown]
# ### Best practices:
#
# Prompt design best practices include:
#
# - Give clear and specific instructions
# - Include few-shot examples
# - Assign a role
# - Add contextual information
# - Use system instructions
# - Structure prompts
# - Instruct the model to explain its reasoning
# - Break down complex tasks
# - Experiment with parameter values
# - Prompt iteration strategies

# %% [markdown]
# ## Prompt health checklist
#
# ### Writing issues
# - Typos
# - Grammar
# - Punctuation
# - Use of undefined jargon
# - Clarity
# - Ambiguity
# - Missing key information
# - Poor word choice
# - Secondary review
#
# ### Issues with instructions and examples
# - Overt manipulation
# - Conflicting instructions and examples
# - Redundant instructions and examples
# - Irrelevant instructions and examples
# - Use of "few-shot" examples
# - Missing output format specification
# - Missing role definition
#
# ### Prompt and system design issues
# - Underspecified task
# - Task outside of model capabilities
# - Too many tasks
# - Non-standard data format
# - Incorrect Chain of Thought (CoT) order
# - Thinking vs. Reasoning
# - Conflicting internal references
# - Prompt injection risk
