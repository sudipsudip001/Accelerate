# %% [markdown]
# # Key Terms and Concepts in Natural Language Processing

# %% [markdown]
# Here’s your text with **backticks added after every `\n\n` and before `:`** where applicable:
#
# ---
#
# Natural language processing (NLP) is a branch of artificial intelligence that deals with analyzing, understanding, and generating human language. Here are some of the key terms and concepts in natural language processing (NLP):
#
# `Tokenization`: Splitting text into individual words, phrases, symbols, or other meaningful elements called tokens. This is an essential first step for processing text.
#
# `Stop words`: Common words like "a", "and", "the" that provide little informational value. Stop words are often filtered out before processing text.
#
# `Stemming`: Reducing words to their root form. For example, "learning" is reduced to "learn". This helps consolidate vocabulary and reduce sparsity.
#
# `Lemmatization`: Similar to stemming but produces valid lemmas or dictionary roots. For example, "better" becomes "good" rather than just removing suffixes.
#
# `Bag-of-words`: A representation of text that describes the occurrence of words within a document. The order of words is ignored.
#
# `N-grams`: Sequences of n consecutive words used to understand word order and local context. For example, "artificial intelligence" becomes a 2-gram.
#
# `POS tagging`: Assigning parts of speech (like noun, verb, adjective) to tokens in text. Useful for disambiguation.
#
# `Named entity recognition`: Identifying and classifying key entities (like people, places, organizations) in text. Essential for understanding meaning.
#
# `Word embeddings`: Representing each word as a high-dimensional numeric vector that encodes semantic meaning based on word usage. Enables mathematical operations.
#
# `Corpus`: Collection of texts used for NLP analysis.
#
# `Syntax`: Structure and grammar of sentences.
#
# `Semantics`: Meaning of language.
#
# `Sentiment analysis`: Identifying emotional tone behind text, like opinions, emotions, attitudes in text.
#
# `Named entity recognition`: Finding and labeling entities like people, places.
#
# `Parsing`: Analyzing sentence structure and relationship between words.
#
# `Co-reference resolution`: Linking words or phrases that refer to the same entity.
#
# `Word sense disambiguation`: Determining meaning of ambiguous words based on context.
#
# `Machine translation`: Automated translation between languages.
#
# `Question answering`: Systems that answer questions based on knowledge.
#
# `Dialog systems`: Automated conversational agents (chatbots).
#
# `Spell correction`: Spell correction identifies and automatically corrects misspellings in text using dictionaries or language models.
#
# `Optical character recognition (OCR)`: OCR converts images of text into machine-readable data, enabling text extraction from scanned documents, images, and videos.
#
# `Natural language generation`: Natural language generation (NLG) creates textual content from data, aiming to produce coherent and contextually appropriate sentences.
#
# `Contextual embeddings`: Contextual embeddings represent words in their surrounding context, enabling richer semantic understanding. Models like BERT and ELMo achieve this by learning from text.
#
# `Language models`: Language models learn language structure and generate probable sequences of words. Examples include GPT-3, which can generate human-like text based on input prompts.
#
# `Probabilistic models`: Probabilistic models use statistical methods and probabilities to model language, allowing for handling uncertainty in text data.
#
# `Linguistic rules`: Linguistic rules encode grammar structures, morphology, and syntax into algorithms for language processing.
#
# `Ontologies`: Ontologies are structured representations of concepts and relationships, often used to model knowledge and support semantic understanding.
#
# `Speech recognition`: Speech recognition converts spoken language to text, enabling voice command and transcription applications.
#
# `Natural language understanding`: Natural language understanding (NLU) derives meaning from text, interpreting user intents and making sense of linguistic input.
#
# `Discourse analysis`: Discourse analysis studies language use in conversations and texts to understand how sentences and paragraphs connect to convey meaning.
#
# `Coreference`: Determining when multiple expressions refer to the same entity.
#
# `Knowledge graphs`: Knowledge graphs represent interconnected entities and concepts as a graph data model, often used in information retrieval and knowledge management.
#
# `Sequence-to-sequence models`: Sequence-to-sequence models process both input and output sequences, used in tasks like translation, where the model transforms a source sequence into a target sequence.
#
# `Language vectors`: Language vectors represent words or sentences as numerical vectors capturing semantics, allowing for mathematical operations like similarity calculations.
#
# `Transducers`: Transducers are models that process input sequentially while producing output, useful for tasks like speech recognition and translation.
#
# `Morphology`: Morphology studies the internal structure of words and how words are formed, including how roots, prefixes, and suffixes combine.
#
# `Phonology`: Phonology examines the sound systems of languages, including phonemes and how they are organized and used.
#
# `Pragmatics`: Pragmatics explores how context and intent influence language understanding, including how meaning changes based on context.
#
# `Discourse`: Discourse involves connected language across multiple sentences or conversations, providing context for understanding longer texts.
#
# `Anaphora/Cataphora`: Anaphora and cataphora involve linking pronouns or nouns back (anaphora) or forward (cataphora) to other words or phrases for clarity.
#
# `Topic modeling`: Discovering abstract topics in a collection of documents.
#
# `Information extraction`: Extracting structured info like entities, relationships, events from text.
#
# `Summarization`: Generating a summary capturing the main points of a larger text.
#
# `Question generation`: Automatically creating questions from passages of text.
#
# `Coreference resolution`: Determining when two expressions refer to the same entity.
#
# `Word sense disambiguation`: Identifying the correct sense of ambiguous words.
#
# `Optical character recognition`: Converting images of text into machine-readable text.
#
# `Multimodal learning`: Combining language with other modes like vision or speech.
#
# `Phonetics`: The study of speech sounds and pronunciation.
#
# `Phonology`: The study of the sound systems of languages.
#
# `Morphophonology`: Studying how morphology interacts with phonology.
#
# `Sociolinguistics`: Studying language in social contexts.
#
# `Forensic linguistics`: Forensic linguistics applies linguistic analysis in legal contexts, aiding in areas such as authorship attribution and linguistic profiling.
#
# `Psycholinguistics`: Psycholinguistics studies the psychological processes of language use, including how language is acquired, comprehended, and produced.
#
# `Neurolinguistics`: Neurolinguistics examines the neuroscience of language processing in the brain, exploring how language and cognition are connected.
#
# `Stylistics`: Stylistics analyzes and understands linguistic style, exploring how language is used to create tone, mood, and impact.
#
# `Readability`: Measuring how easy a text is to read and understand.
#
# `Text simplification`: Reducing complexity of text to make it more readable.
#
# `Code-switching`: Code-switching involves switching between languages or dialects in speech or writing, often reflecting bilingual or multilingual speakers' linguistic flexibility.
#
# `Multiword expressions`: Words that act as a single semantic unit like "case study".
#
# `Evaluation metrics`: Ways to quantitatively evaluate NLP systems like BLEU, ROUGE.
#
# `Low resource languages`: Low-resource languages have limited digital data available, making NLP tasks more challenging due to the lack of training resources.
