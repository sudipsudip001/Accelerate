# %% [markdown]
# # Embeddings
#
# Embeddings are (useful) numerical representations of data learned implicitly through model training.
#
# Learning embedding spaces will have some underlying structure so that similar concepts are located close together.
#
# ![embeddings example](./embedding.png)
#
# The key limiation of previously mentioned models is that they are restricted to a single data modality e.g. text or images. preventing cross-modal applications like image captioning, content moderation, etc.

# %% [markdown]
# ## Multimodal embeddings
#
# ![multimodal embedding picture](./multimodal_embedding.png)
#
# To merge the representations we have multimodal embeddings. Though text and images may look very different to us, in a neural network, these are represented via the same mathematical object, i.e. a vector. Therefore in principle, text, images, or other data modality can be processed by a single model.
#
# This fact underlies **multimodal embeddings**, which represent multiple data modalities in the same vector space such that similar concepts are co-located (independent of their original representations).
#
# e.g. CLIP encodes text and images into a shared embedding space. A key insight from CLIP is that by aligning text and image representations, the model is capable of 0-shot image classification on arbitrary set of target classes since an input text can be treated as a class label.
#
# Virtually any data modalities can be aligned in this way e.g. text-audio, audio-image, text-EEG, image-tabular, and text-audio. This unlocks use cases such as video captioning, advanced OCR, audio transcription, etc.

# %% [markdown]
# ## Contrastive Learning
#
# Contrastive Learning is standard approach to aligning disparate embedding space. The whole idea is to **represent different views of the same information similarly.**
#
# This consists of learning representations that maximize the similarity between positive pairs and **minimize the similarity of negative pairs.**
#
# Two aspects of CL contribute to its effectiveness:
#
# 1. Since positive and negative pairs can be curated from data's inherent structure (e.g. metadata from web images), CL training data do not require **manual labeling**, which unlocks larger-scale training and more powerful representations.
#
# 1. It simultaneously maximizes positive and minimizes negative pair similarity via a special loss function, as demonstrated by CLIP.
